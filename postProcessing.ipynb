# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import copy as copy

# %%
path = 'workspace/data/'

# BC CHeng, No Viscous, No Smoothing

df1 = pd.read_csv(path+"iteration_1")

# BC CHeng, No Viscous, No Smoothing, boundary iterations 
# with predicted variables

df2 = pd.read_csv(path+"iteration_2")

# BC CHeng, No Viscous, No Smoothing,added predicted density
# to the calculations 

df3 = pd.read_csv(path+"iteration_3")

# %%
plt.plot(df3.pressureIterationation,df3.predicted_error)

# %%
plt.yscale('log')
plt.plot(df1.pressureIterationation,df1.predicted_error)
plt.plot(df2.pressureIterationation,df2.predicted_error)
plt.plot(df3.pressureIterationation,df3.predicted_error)
plt.show()
